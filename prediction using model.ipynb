# %%
import os
import cv2
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Step 1: Load your trained classification model
model = load_model("modellac91.h5")

# Step 2: Read and preprocess the test image
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    resized_img = cv2.resize(img, (119, 119))  # Resize to match the input size of the model
    normalized_img = resized_img / 255.0  # Normalize the image
    preprocessed_img = np.expand_dims(normalized_img, axis=0)  # Add batch dimension
    return preprocessed_img


# Step 3: Use the model to make predictions
def classify_chromosome(image):
    prediction = model.predict(image)
    predicted_class = np.argmax(prediction)
    probability = prediction[0][predicted_class] * 100
    return predicted_class, probability

# Step 4: Test the model on an image and print the predicted class and probability
image_path = "C:/Users/HP/Desktop/mini project/noo/23/23_55.bmp"
preprocessed_image = preprocess_image(image_path)
predicted_class, probability = classify_chromosome(preprocessed_image)

 # Display the image
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()



print("Predicted Class:", predicted_class+1)
print("Probability:", probability)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Class: 16
# Probability: 99.99527931213379

# %%
import os
import cv2
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Step 1: Load your trained classification model
model = load_model("modellac91.h5")

# Step 2: Read and preprocess the test image
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    resized_img = cv2.resize(img, (119, 119))  # Resize to match the input size of the model
    normalized_img = resized_img / 255.0  # Normalize the image
    return normalized_img

# Step 3: Use the model to make predictions
def classify_chromosome(image):
    prediction = model.predict(image.reshape(1, 119, 119, 3))
    predicted_class = np.argmax(prediction)
    probability = prediction[0][predicted_class] * 100
    return predicted_class, probability

# Step 4: Test the model on images in a folder
folder_path = "C:/Users/HP/Desktop/mini project/google/"
image_files = os.listdir(folder_path)

for image_file in image_files:
    if image_file.endswith(".bmp"):  # Assuming all images are in PNG format
        image_path = os.path.join(folder_path, image_file)
        preprocessed_image = preprocess_image(image_path)
        
        
        # Display the image
        image = cv2.imread(image_path)
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()
       
         # Get prediction
        predicted_class, probability = classify_chromosome(preprocessed_image)
        
        # Display prediction
        print("Image:", image_file)
        if predicted_class==15:
           print("Chromosome number 23")
        elif predicted_class==0:
           print("Chromosome number 1")
        elif predicted_class==11:
           print("Chromosome number 2")
        elif predicted_class==16:
           print("Chromosome number 3")
        elif predicted_class==17:
           print("Chromosome number 4")
        elif predicted_class==18:
           print("Chromosome number 5")
        elif predicted_class==19:
           print("Chromosome number 6")
        elif predicted_class==20:
           print("Chromosome number 7")
        elif predicted_class==21:
           print("Chromosome number 8")
        elif predicted_class==22:
           print("Chromosome number 9")
        elif predicted_class==1:
           print("Chromosome number 10")
        elif predicted_class==2:
           print("Chromosome number 11")
        elif predicted_class==3:
           print("Chromosome number 12")
        elif predicted_class==4:
           print("Chromosome number 13")
        elif predicted_class==5:
           print("Chromosome number 14")
        elif predicted_class==6:
           print("Chromosome number 15")
        elif predicted_class==7:
           print("Chromosome number 16")
        elif predicted_class==8:
           print("Chromosome number 17")
        elif predicted_class==9:
           print("Chromosome number 18")
        elif predicted_class==10:
           print("Chromosome number 19")
        elif predicted_class==12:
           print("Chromosome number 20")
        elif predicted_class==13:
           print("Chromosome number 21")
        elif predicted_class==14:
           print("Chromosome number 22")
        #print("Predicted Class:", predicted_class)
        print("Probability:", probability)
        if probability<=50:
            print("NOT CONFIDENT")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 94 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A327A15260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
if predicted_class==15:
    print("Chromosome number 23")
elif predicted_class==0:
    print("Chromosome number 1")
elif predicted_class==11:
    print("Chromosome number 2")
elif predicted_class==16:
    print("Chromosome number 3")
elif predicted_class==17:
    print("Chromosome number 4")
elif predicted_class==18:
    print("Chromosome number 5")
elif predicted_class==19:
    print("Chromosome number 6")
elif predicted_class==20:
    print("Chromosome number 7")
elif predicted_class==21:
    print("Chromosome number 8")
elif predicted_class==22:
    print("Chromosome number 9")
elif predicted_class==1:
    print("Chromosome number 10")
elif predicted_class==2:
    print("Chromosome number 11")
elif predicted_class==3:
    print("Chromosome number 12")
elif predicted_class==4:
    print("Chromosome number 13")
elif predicted_class==5:
    print("Chromosome number 14")
elif predicted_class==6:
    print("Chromosome number 15")
elif predicted_class==7:
    print("Chromosome number 16")
elif predicted_class==8:
    print("Chromosome number 17")
elif predicted_class==9:
    print("Chromosome number 18")
elif predicted_class==10:
    print("Chromosome number 19")
elif predicted_class==12:
    print("Chromosome number 20")
elif predicted_class==13:
    print("Chromosome number 21")
elif predicted_class==14:
    print("Chromosome number 22")
